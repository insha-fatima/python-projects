# %%
Name = input("Name: ")
Profession = input("Profession: ")
try:
   print(f"Hello {Name}! Your profession {Profession}, is amazing and you give good interview according to your profesion,Now wait for the call.This company will\
     hire you if you are capabale for this job!")
   print("Thanks")
except Exception as e:
   print(e)
# Out:
# Name: insha
# Profession: programmer
# Hello insha! Your profession programmer, is amazing and you give good interview according to your profesion,Now wait for the call.This company will     hire you if you are capabale for this job!
# Thanks

# %%
Adj1 = input("Ajective: ")
Adj2 = input("Ajective: ")
Verb1 = input("Verb: ")
print(f"Today, we are here to discuss about {Verb1}.So basically {Verb1} is very {Adj1} untill its up to us that how we take this.Our session is about to share some {Adj2} facts about {Verb1}.In our class, there are many students that they already know {Verb1} because they are working and learnt {Verb1}.So those people can help us to understand {Verb1} and solve our any query related to {Verb1}.\
  In todays fast paced world {Verb1} is using everywhere either a small toy of a kid or in a large machineries.So its up to us to do more work on our {Verb1} skills and do more best for our country which will make our country the best technological country in the world.")
# Out:
# Ajective: interesting
# Ajective: amazing
# Verb: programming
# Today, we are here to discuss about programming.So basically programming is very interesting untill its up to us that how we take this.Our session is about to share some amazing facts about programming.In our class, there are many students that they already know programming because they are working and learntprogramming.So those people can help us to understand programming and solve our any query related to programming.  In todays fast paced world programming is using everywhere either a small toy of a kid or in a large machineries.So its up to us to do more work on our programming skills and do more best for our country which will make our country the best technological country in the world.
